# %%
# Import the Kagglehub library
import kagglehub
import os
import pandas as pd

# 1. Download the specific IBM AML dataset
print("Downloading dataset...")
path = kagglehub.dataset_download('ealtman2019/ibm-transactions-for-anti-money-laundering-aml')

print("Path to dataset files:", path)

# 2. Locate the exact CSV we need for the pipeline
csv_path = os.path.join(path, "HI-Small_Trans.csv")

# 3. Load it into Pandas to verify
if os.path.exists(csv_path):
    print("\nLoading HI-Small_Trans.csv into Pandas...")
    df = pd.read_csv(csv_path)
    display(df.head())
else:
    print("\nCould not find HI-Small_Trans.csv in the downloaded files.")
    # Show what files were actually downloaded so you can adjust the name if needed
    print("Files found in directory:", os.listdir(path))
